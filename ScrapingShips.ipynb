# %%
from multiprocessing import Pool
from bs4 import BeautifulSoup
import requests
import csv


def get_urls():
    counter = 0
    length = 0
    lengthDiff = 25 #difference between upper and lower bound of length of the searched ships
    maxLength = 425
    GT = 0
    GTDiff = 100 
    maxGT = 10000
    #open csv and write
    with open('ships', 'w') as shipTable:
        writer = csv.writer(shipTable)

        #write header
        header = ['name', 'MMSI', 'IMO', 'country']
        writer.writerow(header)
        
        while(length + lengthDiff <= maxLength):
            while(GT <= maxGT):
                for page in range(1,201):
                    side_url = 'https://www.vesselfinder.com/vessels?page='+ str(page) 
                    side_url += '&minLength=' + str(length) + '&maxLength=' +str(length+ lengthDiff)
                    side_url += '&minGT=' + str(GT) + '&maxGT=' + str(GT+GTDiff) + '&type=6'
                    # lines = scrapeShipPage(side_url)
                    # lines = scrapeShipPage(side_url)
                    yield side_url
                    # for line in lines:
                    #     writer.writerow(line)
                    #     counter += 1
                    #     print(counter)
                GT += GTDiff
            GT = 0
            length +=  lengthDiff

# %%
def scrapeShipPage(side_url):
    lines = []
    
    html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text

    #get content
    soup = BeautifulSoup(html_text, 'lxml') 
        
    ships = soup.find_all('td', class_ = 'v2')

    
    #extract ship info
    for ship in ships:
        link = ship.find('a', class_ = 'ship-link')['href']
        link = link.replace('/vessels/', '')
        country = ship.find('div', class_ = 'flag-icon-med flag-icon')['title']

        line = '-'
        positions = [pos for pos, char in enumerate(link) if char == line]
        mMSI = link[positions[-1]+1:]
        iMO = link[positions[-3]+1:positions[-2]]
        name = link[:positions[-4]].replace('-', ' ')

        lines.append([name, mMSI, iMO, country])
        
    return lines

# %%
from tqdm import tqdm
pool = Pool(32)
urls = list(get_urls())
results = list(tqdm(pool.imap(scrapeShipPage, urls), total=len(urls)))
# Out:
#   0%|          | 839/343400 [00:44<5:03:19, 18.82it/s] Process ForkPoolWorker-41:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-46:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-33:
# Traceback (most recent call last):
# Process ForkPoolWorker-49:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-63:
# Traceback (most recent call last):
# Process ForkPoolWorker-34:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-51:
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/tmp/ipykernel_714829/4101606577.py", line 4, in scrapeShipPage
#     html_text = requests.get(side_url, headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}).text
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 816, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 816, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 816, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 816, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 816, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 816, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "<string>", line 3, in raise_from
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 627, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 358, in connect
#     self.sock = conn = self._new_conn()
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 627, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 816, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 627, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 566, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 627, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 566, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 627, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 566, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/sessions.py", line 745, in send
#     r.content
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 816, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/home/paul/venv/lib/python3.8/site-packages/requests/models.py", line 899, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 627, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
# ...
#     conn.connect()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 532, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
# KeyboardInterrupt
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "/usr/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 532, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 566, in read
#     data = self._fp_read(amt) if not fp_closed else b""
# KeyboardInterrupt
#   File "<string>", line 3, in raise_from
#   File "<string>", line 3, in raise_from
#   File "/usr/lib/python3.8/http/client.py", line 316, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.8/http/client.py", line 459, in read
#     n = self.readinto(b)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "/usr/lib/python3.8/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 532, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 414, in connect
#     self.sock = ssl_wrap_socket(
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/http/client.py", line 459, in read
#     n = self.readinto(b)
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "/usr/lib/python3.8/http/client.py", line 1348, in getresponse
#     response.begin()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/response.py", line 532, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/usr/lib/python3.8/http/client.py", line 459, in read
#     n = self.readinto(b)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 1042, in _validate_conn
#     conn.connect()
#   File "/usr/lib/python3.8/http/client.py", line 459, in read
#     n = self.readinto(b)
#   File "/usr/lib/python3.8/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.8/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# KeyboardInterrupt
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/usr/lib/python3.8/http/client.py", line 316, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/usr/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.8/http/client.py", line 277, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# KeyboardInterrupt
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 358, in connect
#     self.sock = conn = self._new_conn()
#   File "/usr/lib/python3.8/http/client.py", line 459, in read
#     n = self.readinto(b)
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 449, in ssl_wrap_socket
#     ssl_sock = _ssl_wrap_socket_impl(
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
# KeyboardInterrupt
#   File "/usr/lib/python3.8/http/client.py", line 1348, in getresponse
#     response.begin()
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/http/client.py", line 1348, in getresponse
#     response.begin()
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/usr/lib/python3.8/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/usr/lib/python3.8/http/client.py", line 503, in readinto
#     n = self.fp.readinto(b)
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# KeyboardInterrupt
#   File "/usr/lib/python3.8/http/client.py", line 316, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/usr/lib/python3.8/http/client.py", line 277, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.8/http/client.py", line 316, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 500, in wrap_socket
#     return self.sslsocket_class._create(
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/http/client.py", line 277, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.8/http/client.py", line 277, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 1040, in _create
#     self.do_handshake()
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.8/ssl.py", line 1309, in do_handshake
#     self._sslobj.do_handshake()
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
#   File "/home/paul/venv/lib/python3.8/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
# KeyboardInterrupt
#   File "/usr/lib/python3.8/ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /usr/lib/python3.8/multiprocessing/pool.py:851, in IMapIterator.next(self, timeout)
#     850 try:
# --> 851     item = self._items.popleft()
#     852 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/paul/projects/SuspiciousS2S/ScrapingShips.ipynb Cell 3 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/paul/projects/SuspiciousS2S/ScrapingShips.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> pool = Pool(32)
#       <a href='vscode-notebook-cell:/home/paul/projects/SuspiciousS2S/ScrapingShips.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> urls = list(get_urls())
# ----> <a href='vscode-notebook-cell:/home/paul/projects/SuspiciousS2S/ScrapingShips.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> results = list(tqdm(pool.imap(scrapeShipPage, urls), total=len(urls)))
#
# File ~/venv/lib/python3.8/site-packages/tqdm/std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File /usr/lib/python3.8/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     854     self._pool = None
#     855     raise StopIteration from None
# --> 856 self._cond.wait(timeout)
#     857 try:
#     858     item = self._items.popleft()
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:
